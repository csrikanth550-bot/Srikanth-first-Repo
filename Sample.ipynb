# %%
print("Hello")
# Out:
# Hello

# %%
age=24
_age=24
age_1=24

# %%
type(age)
# Out:
# int

# %%
#assiging value to the variable - comment

# %%
item=30
"""
ajldjf
fjdejfk
fdslkfjkfj
"""
# Out:
# '\najldjf\nfjdejfk\nfdslkfjkfj\n'
